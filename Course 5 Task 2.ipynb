# %%
import pandas as pd

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
credit.dropna()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit['age_bucket']=pd.cut(credit['AGE'],6,labels=['21-29','30-39','40-49','50-59','60-69','70-79'])

# %%
credit.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# ...

# %%
credit['limit_bal_bucket']=pd.cut(credit['LIMIT_BAL'],20,labels=['10,000-50,000','51,000-100,000','101,000-150,000','151,000-200,000','201,000-250,000','251,000-300,000','301,000-350,000','351,000-400,000','401,000-450,000','451,000-500,000','501,000-550,000','551,000-600,000','601,000-650,000','651,000-700,000','701,000-750,000','751,000-800,000','801,000-850,000','851,000-900,000','901,000-950,000','951,000-1,000,000'])

# %%
credit.head(30)
# Out:
#     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    1      20000    2          2         1   24      2      2     -1     -1
# 1    2     120000    2          2         2   26     -1      2      0      0
# 2    3      90000    2          2         2   34      0      0      0      0
# 3    4      50000    2          2         1   37      0      0      0      0
# 4    5      50000    1          2         1   57     -1      0     -1      0
# 5    6      50000    1          1         2   37      0      0      0      0
# 6    7     500000    1          1         2   29      0      0      0      0
# 7    8     100000    2          2         2   23      0     -1     -1      0
# 8    9     140000    2          3         1   28      0      0      2      0
# 9   10      20000    1          3         2   35     -2     -2     -2     -2
# 10  11     200000    2          3         2   34      0      0      2      0
# ...

# %%
credit.to_csv(r'credit_data_pre_process.csv',)

# %%
import pandas as pd

# %%
credit2 = pd.read_csv('credit_data_pre_process.csv',)

# %%
credit2
# Out:
#        Unnamed: 0     ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  \
# 0               0      1      20000    2          2         1   24      2
# 1               1      2     120000    2          2         2   26     -1
# 2               2      3      90000    2          2         2   34      0
# 3               3      4      50000    2          2         1   37      0
# 4               4      5      50000    1          2         1   57     -1
# ...           ...    ...        ...  ...        ...       ...  ...    ...
# 29995       29995  29996     220000    1          3         1   39      0
# 29996       29996  29997     150000    1          3         2   43     -1
# 29997       29997  29998      30000    1          2         2   37      4
# 29998       29998  29999      80000    1          3         1   41      1
# 29999       29999  30000      50000    1          2         1   46      0
#
#        PAY_2  PAY_3  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
header = credit2.dtypes.index
print(header)
# Out:
# Index(['Unnamed: 0', 'ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'age_bucket', 'limit_bal_bucket'],
#       dtype='object')

# %%
plt.hist(credit2['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit2['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.plot(credit2['LIMIT_BAL'])
plt.show()

# %%
x = credit2['PAY_0']
y = credit2['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
header = credit2.dtypes.index
print(header)
# Out:
# Index(['Unnamed: 0', 'ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1',
#        'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
#        'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'age_bucket', 'limit_bal_bucket'],
#       dtype='object')

# %%
A = credit2['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = credit2.corr()
print(corrMat)
# Out:
#                             Unnamed: 0        ID  LIMIT_BAL       SEX  \
# Unnamed: 0                    1.000000  1.000000   0.026179  0.018497
# ID                            1.000000  1.000000   0.026179  0.018497
# LIMIT_BAL                     0.026179  0.026179   1.000000  0.024755
# SEX                           0.018497  0.018497   0.024755  1.000000
# EDUCATION                     0.039177  0.039177  -0.219161  0.014232
# MARRIAGE                     -0.029079 -0.029079  -0.108139 -0.031389
# AGE                           0.018678  0.018678   0.144713 -0.090874
# PAY_0                        -0.030575 -0.030575  -0.271214 -0.057643
# PAY_2                        -0.011215 -0.011215  -0.296382 -0.070771
# PAY_3                        -0.018494 -0.018494  -0.286123 -0.066096
# PAY_4                        -0.002735 -0.002735  -0.267460 -0.060173
# PAY_5                        -0.022199 -0.022199  -0.249411 -0.055064
# ...

# %%
covMat = credit2.cov()
print(covMat)
# Out:
#                               Unnamed: 0            ID     LIMIT_BAL  \
# Unnamed: 0                  7.500250e+07  7.500250e+07  2.941664e+07
# ID                          7.500250e+07  7.500250e+07  2.941664e+07
# LIMIT_BAL                   2.941664e+07  2.941664e+07  1.683446e+10
# SEX                         7.835638e+01  7.835638e+01  1.571051e+03
# EDUCATION                   2.681543e+02  2.681543e+02 -2.247403e+04
# MARRIAGE                   -1.314525e+02 -1.314525e+02 -7.323670e+03
# AGE                         1.491057e+03  1.491057e+03  1.730767e+05
# PAY_0                      -2.975726e+02 -2.975726e+02 -3.954593e+04
# PAY_2                      -1.162770e+02 -1.162770e+02 -4.603765e+04
# PAY_3                      -1.916922e+02 -1.916922e+02 -4.443225e+04
# PAY_4                      -2.769132e+01 -2.769132e+01 -4.057181e+04
# PAY_5                      -2.178600e+02 -2.178600e+02 -3.667056e+04
# PAY_6                      -2.018774e+02 -2.018774e+02 -3.509308e+04
# ...

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
credit2.groupby('age_bucket')['age_bucket'].count()
# Out:
# age_bucket
# 21-29    11013
# 30-39    10713
# 40-49     6005
# 50-59     1930
# 60-69      314
# 70-79       25
# Name: age_bucket, dtype: int64

# %%
fg = sns.catplot('age_bucket', data=credit2, kind='count', aspect=1.5)
fg.set_xlabels('Age')

# %%
# Number of men and women in each age range
credit2.groupby(['SEX', 'age_bucket'])['SEX'].count()
# Out:
# SEX  age_bucket
# 1    21-29         3842
#      30-39         4363
#      40-49         2587
#      50-59          917
#      60-69          166
#      70-79           13
# 2    21-29         7171
#      30-39         6350
#      40-49         3418
#      50-59         1013
#      60-69          148
#      70-79           12
# Name: SEX, dtype: int64

# %%
g = sns.catplot('age_bucket', data=credit2, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('age_bucket')

# %%
credit2.groupby('default payment next month')['default payment next month'].count()
# Out:
# default payment next month
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
g = sns.catplot('age_bucket', data=credit2, hue='default payment next month', kind='count', aspect=1.75)
g.set_xlabels('age_bucket')

# %%
g = sns.catplot('SEX', data=credit2, hue='default payment next month', kind='count', aspect=1.75)
g.set_xlabels('SEX')

# %%
g = sns.catplot('limit_bal_bucket', data=credit2, hue='default payment next month', kind='count', aspect=5.25)
g.set_xlabels('limit_bal_bucket')

# %%
g = sns.catplot('PAY_0', data=credit2, hue='default payment next month', kind='count', aspect=1.75)
g.set_xlabels('PAY_0')

# %%
fig = sns.FacetGrid(credit2, hue='default payment next month', aspect=4)
fig.map(sns.kdeplot, 'AGE', shade=True)
oldest = credit2['AGE'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Age Grouped Default Prediction')
fig.add_legend()

# %%
fig = sns.FacetGrid(credit2, hue='default payment next month', aspect=4)
fig.map(sns.kdeplot, 'PAY_0', shade=True)
oldest = credit2['PAY_0'].max()
fig.set(xlim=(-2,oldest))
fig.set(title='Distribution of PAY_0 Status Grouped Default Prediction')
fig.add_legend()

# %%
fig = sns.FacetGrid(credit2, hue='default payment next month', aspect=4)
fig.map(sns.kdeplot, 'EDUCATION', shade=True)
oldest = credit2['EDUCATION'].max()
fig.set(xlim=(0,oldest))
fig.set(title='Distribution of Education Level Grouped Default Prediction')
fig.add_legend()

# %%
g = sns.catplot('EDUCATION', data=credit2, hue='default payment next month', kind='count', aspect=5.25)
g.set_xlabels('EDUCATION')
